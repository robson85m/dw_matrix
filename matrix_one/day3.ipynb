# %%
#!pip install datadotworld
#!pip install datadotworld[pandas]

# %%
#!dw configure

# %%
from google.colab import drive
import pandas as pd
import numpy as np
import datadotworld as dw

# %%
#drive.mount('/content/drive')

# %%
cd 'drive/My Drive/Colab Notebooks/dw_matrix'
# Out:
# /content/drive/My Drive/Colab Notebooks/dw_matrix

# %%
# !echo 'data' >.gitignore

# %%
data = dw.load_dataset('datafiniti/womens-shoe-prices')

# %%
data.dataframes
# Out:
# LazyLoadedDict({'7003_1': LazyLoadedValue(<pandas.DataFrame>), 'datafiniti_womens_shoes': LazyLoadedValue(<pandas.DataFrame>), 'datafiniti_womens_shoes_jun19': LazyLoadedValue(<pandas.DataFrame>)})

# %%
df = data.dataframes['7003_1']
df.shape
# Out:
# (19045, 47)

# %%
df.sample(4)
# Out:
#                          id asins      brand  ...          upc websiteids weight
# 8365   AVpfGn-u1cnluZ0-d-ov   NaN     RUBIES  ...          NaN        NaN    NaN
# 2593   AVpe6KPWilAPnD_xQn7m   NaN     Levi's  ...  8.86878E+11        NaN    NaN
# 12993  AVpfIekbLJeJML433E0-   NaN     Sara Z  ...  7.31351E+11        NaN    NaN
# 11430  AVpfJccPLJeJML433Zxt   NaN  unbranded  ...  6.92393E+11        NaN    NaN
#
# [4 rows x 47 columns]

# %%
df.columns
# Out:
# Index(['id', 'asins', 'brand', 'categories', 'colors', 'count', 'dateadded',
#        'dateupdated', 'descriptions', 'dimension', 'ean', 'features',
#        'flavors', 'imageurls', 'isbn', 'keys', 'manufacturer',
#        'manufacturernumber', 'merchants', 'name', 'prices_amountmin',
#        'prices_amountmax', 'prices_availability', 'prices_color',
#        'prices_condition', 'prices_count', 'prices_currency',
#        'prices_dateadded', 'prices_dateseen', 'prices_flavor', 'prices_issale',
#        'prices_merchant', 'prices_offer', 'prices_returnpolicy',
#        'prices_shipping', 'prices_size', 'prices_source', 'prices_sourceurls',
#        'prices_warranty', 'quantities', 'reviews', 'sizes', 'skus',
#        'sourceurls', 'upc', 'websiteids', 'weight'],
#       dtype='object')

# %%
df.prices_currency.unique()
# Out:
# array(['USD', 'CAD', 'AUD', 'EUR', nan, 'GBP',
#        'Off Price Direct - Walmart.com', 'new'], dtype=object)

# %%
df.prices_currency.value_counts()
# Out:
# USD                               18199
# CAD                                 638
# AUD                                 118
# EUR                                  64
# GBP                                  15
# Off Price Direct - Walmart.com        1
# new                                   1
# Name: prices_currency, dtype: int64

# %%
df_usd = df[df.prices_currency == 'USD'].copy()

# %%
df_usd.shape
# Out:
# (18199, 47)

# %%
df_usd.prices_amountmin.astype(np.float)
# Out:
# 0         71.99
# 1        250.00
# 2         75.99
# 3         79.98
# 4         26.98
# 5         15.99
# 6         90.00
# 7        318.00
# 8        166.99
# 9         27.98
# 10        39.99
# 11        22.99
# 12        23.99
# 13        19.99
# 14        22.99
# 15        75.00
# 16        29.99
# 17        50.99
# 18        64.95
# 19        69.98
# 20        45.54
# 21        23.98
# 22         1.99
# 23        45.00
# 24        11.99
# 25        18.99
# 26        79.00
# 27        26.99
# 28        34.99
# 29        79.00
#           ...
# 19014    161.99
# 19015     63.59
# 19016     57.24
# 19017    100.00
# 19018     24.99
# 19019     19.99
# 19020     62.99
# 19021     81.99
# 19022    180.00
# 19023    102.99
# 19024     33.99
# 19025     14.99
# 19026     33.99
# 19027      9.99
# 19028     31.95
# 19029     36.99
# 19030     52.67
# 19031     26.39
# 19032     99.95
# 19033     34.99
# 19034     36.93
# 19035     33.24
# 19036     17.99
# 19038     45.81
# 19039     90.00
# 19040    130.00
# 19041     39.99
# 19042     66.00
# 19043     49.98
# 19044     33.99
# Name: prices_amountmin, Length: 18199, dtype: float64

# %%
df_usd['prices_amountmin'] = df_usd.prices_amountmin.astype(np.float)

# %%
df_usd['prices_amountmin'].hist()

# %%
filter_max = np.percentile(df_usd['prices_amountmin'],99)

# %%
df_usd_filter = df_usd[df_usd['prices_amountmin']<filter_max]

# %%
df_usd_filter.prices_amountmin.hist(bins=100)

# %%
cd matrix_one/
# Out:
# /content/drive/My Drive/Colab Notebooks/dw_matrix/matrix_one

# %%
ls
# Out:
# day3.ipynb

# %%
# !git config --global user.email "delan.contar@gmail.com"
# !git config --global user.name "Delan"

# %%
# !git add
